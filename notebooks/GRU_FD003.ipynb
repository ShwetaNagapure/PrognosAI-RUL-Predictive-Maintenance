# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import optuna
from optuna.trial import TrialState

# %%
TRAIN_PATH = "data/train_FD003.txt"
TEST_PATH  = "data/test_FD003.txt"
RUL_PATH   = "data/RUL_FD003.txt"

# %%
SEQ_LEN = 80           # window length (you can try 25–50)
STEP = 1                # stride for training windows
BATCH_SIZE = 128
LR = 0.005296227272721275
EPOCHS = 100
PATIENCE = 20
RUL_CLIP = 200          # cap RUL
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
RANDOM_SEED = 42
torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %%
train_df = pd.read_csv(TRAIN_PATH, sep=" ", header=None).dropna(axis=1, how="all")
test_df  = pd.read_csv(TEST_PATH,  sep=" ", header=None).dropna(axis=1, how="all")
rul_df   = pd.read_csv(RUL_PATH,   sep=" ", header=None)

# consistent columns (first 24 columns typically: unit, cycle, op1..3, s1..21)
cols = ["unit", "cycle"] + [f"op_setting_{i}" for i in range(1,4)] + [f"sensor_{i}" for i in range(1,22)]
train_df = train_df.iloc[:, :len(cols)]
test_df  = test_df.iloc[:, :len(cols)]
train_df.columns = cols
test_df.columns  = cols

# %%
train_max = train_df.groupby("unit")["cycle"].max().to_dict()
train_df["RUL"] = train_df.apply(lambda r: train_max[r["unit"]] - r["cycle"], axis=1)
train_df["RUL"] = train_df["RUL"].clip(upper=RUL_CLIP)

# %%
rul_vals = rul_df.iloc[:,0].values.flatten()
# rul_vals order is engine 1..N (CMAPSS protocol)
# create a mapping engine -> remaining cycles (RUL_final)
test_rul_map = {unit: int(rval) for unit, rval in zip(sorted(test_df["unit"].unique()), rul_vals)}
# Note: We'll clip later when we construct y_test

# %%
selected_features = [
    "op_setting_1","op_setting_2","op_setting_3",
    "sensor_2","sensor_3","sensor_4","sensor_7","sensor_8",
    "sensor_9","sensor_11","sensor_12","sensor_13","sensor_14","sensor_15"
]

# %%
train_df = train_df[["unit","cycle"] + selected_features + ["RUL"]]
# test keep features + unit,cycle
test_df = test_df[["unit","cycle"] + selected_features].copy()

# ----------------------------
# 5) Scaling: fit StandardScaler on training features (global)
#    (StandardScaler is preferred here per your guide)
# ----------------------------
scaler = StandardScaler()
train_df[selected_features] = scaler.fit_transform(train_df[selected_features])
test_df[selected_features]  = scaler.transform(test_df[selected_features])

# %%
def create_train_sequences(df, seq_len=SEQ_LEN, step=STEP):
    X, y = [], []
    for uid in sorted(df["unit"].unique()):
        unit_df = df[df["unit"] == uid].reset_index(drop=True)
        feats = unit_df[selected_features].values
        labels = unit_df["RUL"].values
        L = len(unit_df)
        # create windows
        for start in range(0, L - seq_len + 1, step):
            end = start + seq_len
            X.append(feats[start:end])
            # label corresponds to last time step of the window (end-1)
            y.append(labels[end-1])
    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)
    return X, y

# Build train sequences for all train units
X_all, y_all = create_train_sequences(train_df, SEQ_LEN, STEP)
print(f"All train sequences: {X_all.shape}, {y_all.shape}")
# Out:
# All train sequences: (16820, 80, 14), (16820,)

# %%
units = sorted(train_df["unit"].unique())
n_units = len(units)
# default split: first 80% engines train, rest val (or use fixed 1..80,81..100)
train_units = units[: int(n_units * 0.8)]
val_units   = units[int(n_units * 0.8):]

def create_sequences_by_units(df, units_list, seq_len=SEQ_LEN, step=STEP):
    X, y = [], []
    for uid in units_list:
        unit_df = df[df["unit"] == uid].reset_index(drop=True)
        feats = unit_df[selected_features].values
        labels = unit_df["RUL"].values
        L = len(unit_df)
        for start in range(0, L - seq_len + 1, step):
            end = start + seq_len
            X.append(feats[start:end])
            y.append(labels[end-1])
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

X_train, y_train = create_sequences_by_units(train_df, train_units, SEQ_LEN, STEP)
X_val,   y_val   = create_sequences_by_units(train_df, val_units,   SEQ_LEN, STEP)

print(f"Train: {X_train.shape}, {y_train.shape}   Val: {X_val.shape}, {y_val.shape}")
# Out:
# Train: (13459, 80, 14), (13459,)   Val: (3361, 80, 14), (3361,)

# %%
def build_test_last_windows(test_df, rul_map, seq_len=SEQ_LEN):
    X_test = []
    y_test = []
    units_sorted = sorted(test_df["unit"].unique())
    for uid in units_sorted:
        unit_df = test_df[test_df["unit"] == uid].reset_index(drop=True)
        if len(unit_df) < seq_len:
            # pad at start with first row repeated (rare); simpler to skip but we keep padding
            pad_len = seq_len - len(unit_df)
            pad = np.repeat(unit_df[selected_features].iloc[[0]].values, pad_len, axis=0)
            window = np.vstack([pad, unit_df[selected_features].values])
        else:
            window = unit_df[selected_features].values[-seq_len:]
        X_test.append(window.astype(np.float32))
        # RUL for engine = value from rul_map (this is final remaining cycles)
        true_rul = rul_map[uid]
        y_test.append(min(true_rul, RUL_CLIP))  # apply clipping here
    return np.array(X_test, dtype=np.float32), np.array(y_test, dtype=np.float32), units_sorted

X_test, y_test, test_units = build_test_last_windows(test_df, test_rul_map, SEQ_LEN)
print(f"Test windows: {X_test.shape}, Test labels (engines): {y_test.shape}")
# Out:
# Test windows: (100, 80, 14), Test labels (engines): (100,)

# %%
class SeqDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).unsqueeze(1)  # shape [N,1]
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_ds = SeqDataset(X_train, y_train)
val_ds   = SeqDataset(X_val, y_val)
test_ds  = SeqDataset(X_test, y_test)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False)

# %%
class SmallGRU(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_layers=2, dropout=0.2):
        super().__init__()
        self.gru = nn.GRU(input_dim, hidden_dim, num_layers=num_layers,
                          batch_first=True, dropout=dropout)
        self.fc = nn.Sequential(
            nn.Linear(hidden_dim, 32),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(32, 1)
        )
    def forward(self, x):
        out, _ = self.gru(x)          # out shape: (B, T, hidden_dim)
        last = out[:, -1, :]          # take last time-step hidden vector
        return self.fc(last)

# %% [markdown]
# hyperparameter tune

# %%
import optuna
from optuna.trial import TrialState

def objective(trial):

    # === Search Space === #
    hidden_dim  = trial.suggest_categorical("hidden_dim", [32, 64, 128, 256])
    num_layers  = trial.suggest_int("num_layers", 1, 3)
    dropout     = trial.suggest_float("dropout", 0.1, 0.5)
    lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
    batch_size  = trial.suggest_categorical("batch_size", [32, 64, 128])
    seq_len     = trial.suggest_categorical("seq_len", [30, 50, 60, 80])

    # === Rebuild Sequences For This Trial === #
    X_train_t, y_train_t = create_sequences_by_units(train_df, train_units, seq_len)
    X_val_t,   y_val_t   = create_sequences_by_units(train_df, val_units,   seq_len)

    train_loader = DataLoader(SeqDataset(X_train_t, y_train_t), batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(SeqDataset(X_val_t,   y_val_t),   batch_size=batch_size)

    # === Build Model === #
    model = SmallGRU(
        input_dim=len(selected_features),
        hidden_dim=hidden_dim,
        num_layers=num_layers,
        dropout=dropout
    ).to(DEVICE)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.SmoothL1Loss()

    EPOCHS = 50
    best_val = float("inf")
    patience = 7
    wait = 0

    # === Training Loop === #
    for epoch in range(EPOCHS):

        model.train()
        for Xb, yb in train_loader:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
            optimizer.zero_grad()
            pred = model(Xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()

        # === Validation === #
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for Xb, yb in val_loader:
                Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
                pred = model(Xb)
                val_loss += criterion(pred, yb).item()
        val_loss /= len(val_loader)

        # Report to Optuna
        trial.report(val_loss, epoch)

        # Pruning → kills bad trials early
        if trial.should_prune():
            raise optuna.TrialPruned()

        # Early stopping logic
        if val_loss < best_val:
            best_val = val_loss
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    return best_val

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=40)   # you can try 50, 80, 100

print("Best hyperparameters:")
print(study.best_params)
# Out:
# [I 2025-12-04 21:37:31,769] A new study created in memory with name: no-name-e028cbb6-f98c-4631-9702-d06e288099f9
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2573499216923213 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 21:38:48,336] Trial 0 finished with value: 14.188503124095776 and parameters: {'hidden_dim': 32, 'num_layers': 1, 'dropout': 0.2573499216923213, 'lr': 0.0014769881487100096, 'batch_size': 128, 'seq_len': 80}. Best is trial 0 with value: 14.188503124095776.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 21:44:11,367] Trial 1 finished with value: 16.783675256927136 and parameters: {'hidden_dim': 64, 'num_layers': 3, 'dropout': 0.2869963172092135, 'lr': 0.001069763311124306, 'batch_size': 32, 'seq_len': 60}. Best is trial 0 with value: 14.188503124095776.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 21:51:34,417] Trial 2 finished with value: 17.49193602403005 and parameters: {'hidden_dim': 64, 'num_layers': 3, 'dropout': 0.49308851210059645, 'lr': 0.0002754350488782337, 'batch_size': 128, 'seq_len': 60}. Best is trial 0 with value: 14.188503124095776.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.13213931968656312 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 21:57:26,550] Trial 3 finished with value: 16.849499893188476 and parameters: {'hidden_dim': 256, 'num_layers': 1, 'dropout': 0.13213931968656312, 'lr': 0.0027712097570166375, 'batch_size': 128, 'seq_len': 60}. Best is trial 0 with value: 14.188503124095776.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1428297961816608 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:04:23,477] Trial 4 finished with value: 20.78909437151721 and parameters: {'hidden_dim': 256, 'num_layers': 1, 'dropout': 0.1428297961816608, 'lr': 0.004321777848670643, 'batch_size': 32, 'seq_len': 30}. Best is trial 0 with value: 14.188503124095776.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:04:44,004] Trial 5 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:05:14,306] Trial 6 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:12:53,108] Trial 7 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.34734225729954776 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:12:59,870] Trial 8 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3493485884717991 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:13:08,433] Trial 9 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:13:38,881] Trial 10 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:14:27,505] Trial 11 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:15:13,412] Trial 12 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:15:26,244] Trial 13 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:20:23,156] Trial 14 finished with value: 16.098409166275445 and parameters: {'hidden_dim': 32, 'num_layers': 2, 'dropout': 0.4419818576511795, 'lr': 0.0006067837859602366, 'batch_size': 32, 'seq_len': 60}. Best is trial 0 with value: 14.188503124095776.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.47109411678251284 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:23:01,357] Trial 15 finished with value: 15.06916382402744 and parameters: {'hidden_dim': 32, 'num_layers': 1, 'dropout': 0.47109411678251284, 'lr': 0.007927884864354702, 'batch_size': 32, 'seq_len': 80}. Best is trial 0 with value: 14.188503124095776.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.4181747137336431 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:24:34,268] Trial 16 finished with value: 14.637259553979945 and parameters: {'hidden_dim': 32, 'num_layers': 1, 'dropout': 0.4181747137336431, 'lr': 0.008635647643049735, 'batch_size': 128, 'seq_len': 80}. Best is trial 0 with value: 14.188503124095776.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.4117209777272656 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:24:44,410] Trial 17 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1997521681157765 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:25:53,642] Trial 18 finished with value: 13.318593581517538 and parameters: {'hidden_dim': 32, 'num_layers': 1, 'dropout': 0.1997521681157765, 'lr': 0.005296227272721275, 'batch_size': 128, 'seq_len': 80}. Best is trial 18 with value: 13.318593581517538.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1824401100323551 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:25:58,648] Trial 19 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:29:16,174] Trial 20 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.22254853566030272 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:29:25,297] Trial 21 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3904996871561993 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:29:29,098] Trial 22 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3232740635467942 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:29:33,902] Trial 23 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.10123619397737432 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:29:44,210] Trial 24 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.21462169020556876 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:29:53,170] Trial 25 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:30:05,978] Trial 26 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.267548912669622 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:30:13,956] Trial 27 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.40271823397887235 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:30:41,953] Trial 28 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:31:02,398] Trial 29 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.21242579202676853 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:31:10,538] Trial 30 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.4993514060543264 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:33:07,651] Trial 31 finished with value: 14.474872252851162 and parameters: {'hidden_dim': 32, 'num_layers': 1, 'dropout': 0.4993514060543264, 'lr': 0.007488360286000312, 'batch_size': 32, 'seq_len': 80}. Best is trial 18 with value: 13.318593581517538.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.4895831364794028 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:33:26,562] Trial 32 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.4280922943262785 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:33:45,030] Trial 33 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.4661582974314677 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:33:53,479] Trial 34 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.49907432923558825 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:34:57,834] Trial 35 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.4446542347613786 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:35:03,304] Trial 36 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.37615553797971 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:35:24,858] Trial 37 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1631847441671947 and num_layers=1
#   warnings.warn(
# [I 2025-12-04 22:35:38,681] Trial 38 pruned.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4340\1431936656.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr          = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# [I 2025-12-04 22:36:06,492] Trial 39 pruned.
# Best hyperparameters:
# {'hidden_dim': 32, 'num_layers': 1, 'dropout': 0.1997521681157765, 'lr': 0.005296227272721275, 'batch_size': 128, 'seq_len': 80}

# %%
best_params = study.best_params
print(best_params)
# Out:
# {'hidden_dim': 32, 'num_layers': 1, 'dropout': 0.1997521681157765, 'lr': 0.005296227272721275, 'batch_size': 128, 'seq_len': 80}

# %%
## model Training

# %%
model = SmallGRU(input_dim=len(selected_features), hidden_dim=32, num_layers=1, dropout=0.1997521681157765).to(DEVICE)
# Out:
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1997521681157765 and num_layers=1
#   warnings.warn(

# %%
criterion = nn.SmoothL1Loss()   # Huber-like loss (more robust)
optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,
    patience=5
)

# %%
mae_fn = torch.nn.L1Loss()  # MAE function

best_val = float("inf")
wait = 0

train_losses = []
val_losses = []
train_mae_list = []
val_mae_list = []

best_epoch = -1

for epoch in range(1, EPOCHS + 1):
    
    # -----------------------
    # TRAINING
    # -----------------------
    model.train()
    tloss = 0.0
    tmae  = 0.0
    for Xb, yb in train_loader:
        Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)

        optimizer.zero_grad()
        pred = model(Xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()

        tloss += loss.item() * Xb.size(0)
        tmae  += mae_fn(pred, yb).item() * Xb.size(0)

    tloss = tloss / len(train_loader.dataset)
    tmae  = tmae  / len(train_loader.dataset)

    train_losses.append(tloss)
    train_mae_list.append(tmae)

    # -----------------------
    # VALIDATION
    # -----------------------
    model.eval()
    vloss = 0.0
    vmae  = 0.0
    with torch.no_grad():
        for Xb, yb in val_loader:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)

            pred = model(Xb)
            loss = criterion(pred, yb)

            vloss += loss.item() * Xb.size(0)
            vmae  += mae_fn(pred, yb).item() * Xb.size(0)

    vloss = vloss / len(val_loader.dataset)
    vmae  = vmae  / len(val_loader.dataset)

    val_losses.append(vloss)
    val_mae_list.append(vmae)

    # Step LR scheduler using val loss
    scheduler.step(vloss)

    # Display metrics
    print(
        f"Epoch {epoch:03d} | "
        f"Train Loss: {tloss:.4f} | Val Loss: {vloss:.4f} | "
        f"Train MAE: {tmae:.4f} | Val MAE: {vmae:.4f}"
    )

    # -----------------------
    # EARLY STOPPING
    # -----------------------
    if vloss < best_val - 1e-6:
        best_val = vloss
        best_epoch = epoch
        wait = 0
        torch.save(model.state_dict(), "best_gru_fd003_fixed.pth")
        print(f"  -> New best model saved (Val Loss: {best_val:.6f})")
    else:
        wait += 1
        if wait >= PATIENCE:
            print(f"Early stopping after {epoch} epochs. Best epoch: {best_epoch}")
            break

# Load best model
model.load_state_dict(torch.load("best_gru_fd003_fixed.pth", map_location=DEVICE))
# Out:
# Epoch 001 | Train Loss: 81.2079 | Val Loss: 63.3946 | Train MAE: 81.7059 | Val MAE: 63.8885
#   -> New best model saved (Val Loss: 63.394591)
# Epoch 002 | Train Loss: 39.0689 | Val Loss: 31.4279 | Train MAE: 39.5613 | Val MAE: 31.9171
#   -> New best model saved (Val Loss: 31.427948)
# Epoch 003 | Train Loss: 26.2297 | Val Loss: 26.3478 | Train MAE: 26.7217 | Val MAE: 26.8391
#   -> New best model saved (Val Loss: 26.347751)
# Epoch 004 | Train Loss: 23.2805 | Val Loss: 26.6175 | Train MAE: 23.7713 | Val MAE: 27.1073
# Epoch 005 | Train Loss: 22.8002 | Val Loss: 27.8452 | Train MAE: 23.2912 | Val MAE: 28.3398
# Epoch 006 | Train Loss: 22.6147 | Val Loss: 26.1109 | Train MAE: 23.1049 | Val MAE: 26.6017
#   -> New best model saved (Val Loss: 26.110883)
# Epoch 007 | Train Loss: 22.4337 | Val Loss: 25.9197 | Train MAE: 22.9250 | Val MAE: 26.4087
#   -> New best model saved (Val Loss: 25.919694)
# Epoch 008 | Train Loss: 22.3105 | Val Loss: 27.5039 | Train MAE: 22.8014 | Val MAE: 27.9940
# Epoch 009 | Train Loss: 21.1980 | Val Loss: 25.3844 | Train MAE: 21.6885 | Val MAE: 25.8743
#   -> New best model saved (Val Loss: 25.384369)
# Epoch 010 | Train Loss: 19.0810 | Val Loss: 22.8318 | Train MAE: 19.5702 | Val MAE: 23.3211
#   -> New best model saved (Val Loss: 22.831804)
# Epoch 011 | Train Loss: 16.4873 | Val Loss: 18.7629 | Train MAE: 16.9759 | Val MAE: 19.2506
#   -> New best model saved (Val Loss: 18.762890)
# Epoch 012 | Train Loss: 15.2961 | Val Loss: 16.2276 | Train MAE: 15.7835 | Val MAE: 16.7128
#   -> New best model saved (Val Loss: 16.227579)
# Epoch 013 | Train Loss: 15.0324 | Val Loss: 16.0829 | Train MAE: 15.5203 | Val MAE: 16.5725
#   -> New best model saved (Val Loss: 16.082895)
# Epoch 014 | Train Loss: 14.4141 | Val Loss: 15.1628 | Train MAE: 14.9014 | Val MAE: 15.6468
#   -> New best model saved (Val Loss: 15.162788)
# Epoch 015 | Train Loss: 14.1407 | Val Loss: 15.6554 | Train MAE: 14.6270 | Val MAE: 16.1464
# Epoch 016 | Train Loss: 14.0663 | Val Loss: 15.5484 | Train MAE: 14.5533 | Val MAE: 16.0347
# Epoch 017 | Train Loss: 13.7066 | Val Loss: 15.3983 | Train MAE: 14.1932 | Val MAE: 15.8892
# Epoch 018 | Train Loss: 13.5897 | Val Loss: 14.8361 | Train MAE: 14.0756 | Val MAE: 15.3188
#   -> New best model saved (Val Loss: 14.836143)
# Epoch 019 | Train Loss: 13.0261 | Val Loss: 15.3999 | Train MAE: 13.5124 | Val MAE: 15.8862
# Epoch 020 | Train Loss: 12.8842 | Val Loss: 15.4141 | Train MAE: 13.3700 | Val MAE: 15.8999
# Epoch 021 | Train Loss: 12.9387 | Val Loss: 15.1469 | Train MAE: 13.4239 | Val MAE: 15.6323
# Epoch 022 | Train Loss: 12.6173 | Val Loss: 15.2144 | Train MAE: 13.1030 | Val MAE: 15.6979
# Epoch 023 | Train Loss: 12.4887 | Val Loss: 15.3605 | Train MAE: 12.9747 | Val MAE: 15.8494
# Epoch 024 | Train Loss: 12.3682 | Val Loss: 15.2646 | Train MAE: 12.8530 | Val MAE: 15.7530
# Epoch 025 | Train Loss: 11.9812 | Val Loss: 15.8228 | Train MAE: 12.4653 | Val MAE: 16.3082
# Epoch 026 | Train Loss: 11.9092 | Val Loss: 14.9388 | Train MAE: 12.3933 | Val MAE: 15.4249
# Epoch 027 | Train Loss: 11.8683 | Val Loss: 15.4323 | Train MAE: 12.3530 | Val MAE: 15.9170
# Epoch 028 | Train Loss: 11.7524 | Val Loss: 15.3059 | Train MAE: 12.2366 | Val MAE: 15.7914
# Epoch 029 | Train Loss: 11.5648 | Val Loss: 15.3793 | Train MAE: 12.0488 | Val MAE: 15.8660
# Epoch 030 | Train Loss: 11.6879 | Val Loss: 14.7640 | Train MAE: 12.1721 | Val MAE: 15.2458
#   -> New best model saved (Val Loss: 14.764048)
# Epoch 031 | Train Loss: 11.6081 | Val Loss: 15.2046 | Train MAE: 12.0912 | Val MAE: 15.6910
# Epoch 032 | Train Loss: 11.5889 | Val Loss: 16.3134 | Train MAE: 12.0716 | Val MAE: 16.7999
# Epoch 033 | Train Loss: 11.4684 | Val Loss: 15.8398 | Train MAE: 11.9520 | Val MAE: 16.3247
# Epoch 034 | Train Loss: 11.4295 | Val Loss: 15.6837 | Train MAE: 11.9138 | Val MAE: 16.1719
# Epoch 035 | Train Loss: 11.3573 | Val Loss: 15.7699 | Train MAE: 11.8399 | Val MAE: 16.2584
# Epoch 036 | Train Loss: 11.5393 | Val Loss: 15.9098 | Train MAE: 12.0227 | Val MAE: 16.3970
# Epoch 037 | Train Loss: 11.2388 | Val Loss: 15.4059 | Train MAE: 11.7214 | Val MAE: 15.8931
# Epoch 038 | Train Loss: 11.1680 | Val Loss: 16.2111 | Train MAE: 11.6508 | Val MAE: 16.6964
# Epoch 039 | Train Loss: 10.9471 | Val Loss: 15.7140 | Train MAE: 11.4300 | Val MAE: 16.2008
# Epoch 040 | Train Loss: 11.1079 | Val Loss: 15.6348 | Train MAE: 11.5894 | Val MAE: 16.1222
# Epoch 041 | Train Loss: 11.1377 | Val Loss: 15.5101 | Train MAE: 11.6200 | Val MAE: 15.9966
# Epoch 042 | Train Loss: 11.0810 | Val Loss: 15.5827 | Train MAE: 11.5623 | Val MAE: 16.0700
# Epoch 043 | Train Loss: 10.9473 | Val Loss: 16.0525 | Train MAE: 11.4298 | Val MAE: 16.5398
# Epoch 044 | Train Loss: 10.9107 | Val Loss: 15.6293 | Train MAE: 11.3929 | Val MAE: 16.1151
# Epoch 045 | Train Loss: 10.8932 | Val Loss: 15.6386 | Train MAE: 11.3746 | Val MAE: 16.1246
# Epoch 046 | Train Loss: 10.8579 | Val Loss: 16.4066 | Train MAE: 11.3401 | Val MAE: 16.8940
# Epoch 047 | Train Loss: 10.7268 | Val Loss: 15.9219 | Train MAE: 11.2088 | Val MAE: 16.4087
# Epoch 048 | Train Loss: 10.8444 | Val Loss: 15.9260 | Train MAE: 11.3265 | Val MAE: 16.4124
# Epoch 049 | Train Loss: 10.7573 | Val Loss: 15.8478 | Train MAE: 11.2385 | Val MAE: 16.3345
# Epoch 050 | Train Loss: 10.7875 | Val Loss: 15.9217 | Train MAE: 11.2691 | Val MAE: 16.4076
# Early stopping after 50 epochs. Best epoch: 30
# <All keys matched successfully>

# %%
plt.figure(figsize=(8,4))
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss (SmoothL1)")
plt.title("Train / Val Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
model.eval()
preds = []
with torch.no_grad():
    for Xb, _ in test_loader:
        Xb = Xb.to(DEVICE)
        out = model(Xb)                 # shape (batch,1)
        preds.extend(out.cpu().numpy().flatten())

preds = np.array(preds).flatten()
# preds correspond to engines in test_units order
# y_test we built earlier is clipped RUL from rul_map; use that for metric
y_true = y_test.copy()

# compute RMSE (per-engine)
rmse = math.sqrt(mean_squared_error(y_true, preds))
print(f"TEST RMSE (per-engine): {rmse:.6f}")
# Out:
# TEST RMSE (per-engine): 26.723901

# %%
print("\nEngine | True RUL | Predicted RUL")
for u, t, p in zip(test_units, y_true, preds):
    print(f"{u:3d}    {t:7.2f}     {p:7.2f}")
# Out:
# Engine | True RUL | Predicted RUL
#   1      44.00       46.25
#   2      51.00       48.35
#   3      27.00       31.28
#   4     120.00      191.78
#   5     101.00      114.35
#   6      99.00      119.88
#   7      71.00       50.18
#   8      55.00       44.22
#   9      55.00       52.07
#  10      66.00       64.36
#  11      77.00       74.68
#  12     115.00       86.93
#  13     115.00      111.09
#  14      31.00       29.89
#  15     108.00      167.08
#  16      56.00       74.10
#  17     136.00      132.73
#  18     132.00      110.75
#  19      85.00      126.76
#  20      56.00       53.53
#  21      18.00       16.79
#  22     119.00      117.16
#  23      78.00       76.76
#  24       9.00        9.93
#  25      58.00       46.16
#  26      11.00       11.90
#  27      88.00      142.00
#  28     144.00      183.56
#  29     124.00       95.75
#  30      89.00       87.59
#  31      79.00       74.25
#  32      55.00       71.52
#  33      71.00       66.28
#  34      65.00       78.27
#  35      87.00       95.28
#  36     137.00      165.70
#  37     145.00      136.78
#  38      22.00       24.43
#  39       8.00        7.90
#  40      41.00       39.21
#  41     131.00      171.42
#  42     115.00      159.65
#  43     128.00      182.92
#  44      69.00       61.76
#  45     111.00      182.78
#  46       7.00        8.47
#  47     137.00      102.61
#  48      55.00       49.67
#  49     135.00      144.67
#  50      11.00       13.67
#  51      78.00       69.53
#  52     120.00      183.59
#  53      87.00       81.32
#  54      87.00      153.04
#  55      55.00       43.49
#  56      93.00       85.01
#  57      88.00       57.40
#  58      40.00       42.08
#  59      49.00       42.21
#  60     128.00      110.72
#  61     129.00      186.63
#  62      58.00       59.41
#  63     117.00      147.25
#  64      28.00       29.94
#  65     115.00      183.73
#  66      87.00       91.69
#  67      92.00      105.15
#  68     103.00       86.99
#  69     100.00      117.72
#  70      63.00       66.45
#  71      35.00       32.06
#  72      45.00       45.67
#  73      99.00      108.83
#  74     117.00      200.01
#  75      45.00       51.32
#  76      27.00       26.56
#  77      86.00       66.28
#  78      20.00       21.04
#  79      18.00       22.70
#  80     133.00      184.26
#  81      15.00       17.34
#  82       6.00        4.32
#  83     145.00      102.56
#  84     104.00       91.96
#  85      56.00       79.13
#  86      25.00       22.33
#  87      68.00       56.68
#  88     144.00      159.67
#  89      41.00       63.39
#  90      51.00       46.96
#  91      81.00      105.97
#  92      14.00       14.80
#  93      67.00       84.09
#  94      10.00        7.17
#  95     127.00      115.50
#  96     113.00      106.57
#  97     123.00      185.16
#  98      17.00       15.84
#  99       8.00        8.28
# 100      28.00       29.70

# %%
print("len(y_true):", len(y_true))
print("len(preds):", len(preds))
print("len(test_units):", len(test_units))
# Out:
# len(y_true): 100
# len(preds): 100
# len(test_units): 100

# %%
import torch
import torch.nn as nn

selected_features = [
    "op_setting_1","op_setting_2","op_setting_3",
    "sensor_2","sensor_3","sensor_4","sensor_7","sensor_8",
    "sensor_9","sensor_11","sensor_12","sensor_13","sensor_14","sensor_15"
]

class SmallGRU(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_layers=2, dropout=0.2):
        super().__init__()
        self.gru = nn.GRU(
            input_dim, hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout
        )
        self.fc = nn.Sequential(
            nn.Linear(hidden_dim, 32),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(32, 1)
        )

    def forward(self, x):
        out, _ = self.gru(x)
        last = out[:, -1, :]
        return self.fc(last)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = SmallGRU(input_dim=len(selected_features), hidden_dim=32, num_layers=1, dropout=0.1997521681157765).to(DEVICE)

model.load_state_dict(torch.load("best_gru_fd003_fixed.pth", map_location=DEVICE))

model.eval()

print("Loaded model successfully!")
# Out:
# Loaded model successfully!
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1997521681157765 and num_layers=1
#   warnings.warn(

# %%
errors = preds - y_true

plt.figure(figsize=(10,6))
plt.scatter(test_units, y_true, c=errors, cmap="coolwarm", s=80)
plt.colorbar(label="Prediction Error (Pred - True)")
plt.xlabel("Engine ID")
plt.ylabel("True RUL")
plt.title("Color-coded Error Scatter Plot")
plt.grid(True)
plt.show()

# %%
# %%
import pickle

SCALER_PATH = "scaler_fd003.pkl"

with open(SCALER_PATH, "wb") as f:
    pickle.dump(scaler, f)

print("Scaler saved to:", SCALER_PATH)
# Out:
# Scaler saved to: scaler_fd003.pkl

# %%
# %%
import pickle
import torch

# Load scaler
with open("scaler_fd003.pkl", "rb") as f:
    loaded_scaler = pickle.load(f)

# Load model

model = SmallGRU(input_dim=len(selected_features), hidden_dim=32, num_layers=1, dropout=0.1997521681157765).to(DEVICE)

model.load_state_dict(torch.load("best_gru_fd003_fixed.pth", map_location=DEVICE))
model.to(DEVICE)
model.eval()

print("Model + Scaler loaded successfully.")
# Out:
# Model + Scaler loaded successfully.
# c:\Python312\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1997521681157765 and num_layers=1
#   warnings.warn(

# %%
# %%
UNSEEN_PATH = "data/test_FD003.txt"
UNSEEN_TRUE_RUL_PATH = "data/RUL_FD003.txt"   # Must contain RUL values line-by-line

# Load unseen dataset
unseen_df = pd.read_csv(UNSEEN_PATH, sep=" ", header=None).dropna(axis=1, how="all")
unseen_df = unseen_df.iloc[:, :len(cols)]
unseen_df.columns = cols

# Keep only features
unseen_df = unseen_df[["unit","cycle"] + selected_features]

# Apply saved scaler
unseen_df[selected_features] = loaded_scaler.transform(unseen_df[selected_features])

print(unseen_df.head())
# Out:
#    unit  cycle  op_setting_1  op_setting_2  op_setting_3  sensor_2  sensor_3  \
# 0     1      1     -0.764193     -1.377612           0.0 -0.990129 -0.902925
# 1     1      2      0.284359     -0.697425           0.0 -0.837172 -0.472693
# 2     1      3      0.649073     -1.037519           0.0 -1.487242 -0.924951
# 3     1      4      1.241733      0.322855           0.0 -0.493017 -0.521150
# 4     1      5     -0.034765      0.322855           0.0  0.004095  0.139616
#
#    sensor_4  sensor_7  sensor_8  sensor_9  sensor_11  sensor_12  sensor_13  \
# 0 -0.771639 -0.169846 -0.894321 -0.773819  -1.085443  -0.356616  -0.832566
# 1 -0.570063 -0.303673 -0.831142 -0.879925  -1.118768  -0.368904  -0.389857
# 2 -1.284277 -0.213485 -0.641607 -0.460003  -0.885488  -0.292104  -0.832566
# 3 -0.934332 -0.164028 -0.831142 -0.453997  -0.518905  -0.184586  -0.706078
# 4 -0.881124 -0.286218 -0.388893 -0.776822  -1.585329  -0.350472  -0.642833
#
#    sensor_14  sensor_15
# 0  -0.649725  -0.333427
# 1  -0.409780   0.165661
# 2  -0.360700  -0.675517
# 3  -0.432199  -0.417710
# 4  -0.606098   0.304480

# %%
# %%
def build_unseen_last_windows(df, seq_len=SEQ_LEN):
    X = []
    units_sorted = sorted(df["unit"].unique())
    
    for uid in units_sorted:
        unit_df = df[df["unit"] == uid].reset_index(drop=True)
        
        if len(unit_df) < seq_len:
            pad_len = seq_len - len(unit_df)
            pad = np.repeat(unit_df[selected_features].iloc[[0]].values, pad_len, axis=0)
            window = np.vstack([pad, unit_df[selected_features].values])
        else:
            window = unit_df[selected_features].values[-seq_len:]
            
        X.append(window.astype(np.float32))
        
    return np.array(X, dtype=np.float32), units_sorted

X_unseen, unseen_units = build_unseen_last_windows(unseen_df, SEQ_LEN)
print("X_unseen shape:", X_unseen.shape)
# Out:
# X_unseen shape: (100, 80, 14)

# %%
# %%
true_rul_vals = np.loadtxt(UNSEEN_TRUE_RUL_PATH)
y_unseen = true_rul_vals.astype(np.float32)

print("Loaded true RUL shape:", y_unseen.shape)
# Out:
# Loaded true RUL shape: (100,)

# %%
# %%
X_unseen_tensor = torch.tensor(X_unseen, dtype=torch.float32).to(DEVICE)

preds_unseen = []
with torch.no_grad():
    out = model(X_unseen_tensor)
    preds_unseen = out.cpu().numpy().flatten()

preds_unseen = np.array(preds_unseen)

# %%
# %%
print("\nEngine | True RUL | Predicted RUL")
for u, t, p in zip(unseen_units, y_unseen, preds_unseen):
    print(f"{u:3d}    {t:7.2f}     {p:7.2f}")

rmse_unseen = math.sqrt(mean_squared_error(y_unseen, preds_unseen))
print("\nUNSEEN DATA RMSE:", rmse_unseen)
# Out:
# Engine | True RUL | Predicted RUL
#   1      44.00       46.25
#   2      51.00       48.35
#   3      27.00       31.28
#   4     120.00      191.78
#   5     101.00      114.35
#   6      99.00      119.88
#   7      71.00       50.18
#   8      55.00       44.22
#   9      55.00       52.07
#  10      66.00       64.36
#  11      77.00       74.68
#  12     115.00       86.93
#  13     115.00      111.09
#  14      31.00       29.89
#  15     108.00      167.08
#  16      56.00       74.10
#  17     136.00      132.73
#  18     132.00      110.75
#  19      85.00      126.76
#  20      56.00       53.53
#  21      18.00       16.79
#  22     119.00      117.16
#  23      78.00       76.76
#  24       9.00        9.93
#  25      58.00       46.16
#  26      11.00       11.90
#  27      88.00      142.00
#  28     144.00      183.56
#  29     124.00       95.75
#  30      89.00       87.59
#  31      79.00       74.25
#  32      55.00       71.52
#  33      71.00       66.28
#  34      65.00       78.27
#  35      87.00       95.28
#  36     137.00      165.70
#  37     145.00      136.78
#  38      22.00       24.43
#  39       8.00        7.90
#  40      41.00       39.21
#  41     131.00      171.42
#  42     115.00      159.65
#  43     128.00      182.92
#  44      69.00       61.76
#  45     111.00      182.78
#  46       7.00        8.47
#  47     137.00      102.61
#  48      55.00       49.67
#  49     135.00      144.67
#  50      11.00       13.67
#  51      78.00       69.53
#  52     120.00      183.59
#  53      87.00       81.32
#  54      87.00      153.04
#  55      55.00       43.49
#  56      93.00       85.01
#  57      88.00       57.40
#  58      40.00       42.08
#  59      49.00       42.21
#  60     128.00      110.72
#  61     129.00      186.63
#  62      58.00       59.41
#  63     117.00      147.25
#  64      28.00       29.94
#  65     115.00      183.73
#  66      87.00       91.69
#  67      92.00      105.15
#  68     103.00       86.99
#  69     100.00      117.72
#  70      63.00       66.45
#  71      35.00       32.06
#  72      45.00       45.67
#  73      99.00      108.83
#  74     117.00      200.01
#  75      45.00       51.32
#  76      27.00       26.56
#  77      86.00       66.28
#  78      20.00       21.04
#  79      18.00       22.70
#  80     133.00      184.26
#  81      15.00       17.34
#  82       6.00        4.32
#  83     145.00      102.56
#  84     104.00       91.96
#  85      56.00       79.13
#  86      25.00       22.33
#  87      68.00       56.68
#  88     144.00      159.67
#  89      41.00       63.39
#  90      51.00       46.96
#  91      81.00      105.97
#  92      14.00       14.80
#  93      67.00       84.09
#  94      10.00        7.17
#  95     127.00      115.50
#  96     113.00      106.57
#  97     123.00      185.16
#  98      17.00       15.84
#  99       8.00        8.28
# 100      28.00       29.70
#
# UNSEEN DATA RMSE: 26.7239007279474

# %%
# %%
plt.figure(figsize=(10,5))
plt.plot(unseen_units, y_unseen, marker='o', label="True RUL")
plt.plot(unseen_units, preds_unseen, marker='s', label="Predicted RUL")

plt.title("True vs Predicted RUL (Unseen Data)")
plt.xlabel("Engine ID")
plt.ylabel("RUL")
plt.grid(True)
plt.legend()
plt.show()

# %%
# %%
plt.figure(figsize=(12,6))
width = 0.35

plt.bar(unseen_units, y_unseen, width=width, label="True RUL")
plt.bar(unseen_units + np.array([width]*len(unseen_units)), preds_unseen, width=width, label="Predicted RUL")

plt.title("Bar Comparison of True vs Predicted RUL")
plt.xlabel("Engine ID")
plt.ylabel("RUL")
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
# %%
plt.figure(figsize=(7,7))

plt.scatter(y_unseen, preds_unseen)

plt.title("True vs Predicted RUL (Unseen Data)")
plt.xlabel("True RUL")
plt.ylabel("Predicted RUL")
plt.grid(True)

# Optional: Add a diagonal reference line
min_val = min(min(y_unseen), min(preds_unseen))
max_val = max(max(y_unseen), max(preds_unseen))
plt.plot([min_val, max_val], [min_val, max_val], linestyle='--')

plt.show()
